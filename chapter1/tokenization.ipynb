# %%
# !pip install transformers
## Successfully installed filelock-3.18.0 fsspec-2025.5.1 huggingface-hub-0.32.3 numpy-2.2.6 safetensors-0.5.3 tokenizers-0.21.1 transformers-4.52.4
# Out:
# Collecting transformers
#   Downloading transformers-4.52.4-py3-none-any.whl.metadata (38 kB)
# Collecting filelock (from transformers)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.30.0 (from transformers)
#   Downloading huggingface_hub-0.32.3-py3-none-any.whl.metadata (14 kB)
# Collecting numpy>=1.17 (from transformers)
#   Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: packaging>=20.0 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from transformers) (4.67.1)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.30.0->transformers)
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\guido\miniconda3\envs\langchain_py311\lib\site-packages (from requests->transformers) (2025.4.26)
# Downloading transformers-4.52.4-py3-none-any.whl (10.5 MB)
#    ---------------------------------------- 0.0/10.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.5 MB 4.2 MB/s eta 0:00:03
#    ------------------ --------------------- 4.7/10.5 MB 15.0 MB/s eta 0:00:01
#    -------------------------- ------------- 6.8/10.5 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 10.5/10.5 MB 17.6 MB/s eta 0:00:00
# Downloading huggingface_hub-0.32.3-py3-none-any.whl (512 kB)
# Downloading tokenizers-0.21.1-cp39-abi3-win_amd64.whl (2.4 MB)
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 27.5 MB/s eta 0:00:00
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    -------- ------------------------------- 2.9/12.9 MB 41.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.9 MB 26.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 23.8 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-win_amd64.whl (308 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Installing collected packages: safetensors, numpy, fsspec, filelock, huggingface-hub, tokenizers, transformers
#
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----- ---------------------------------- 1/7 [numpy]
#    ----------- ---------------------------- 2/7 [fsspec]
#    ---------------------- ----------------- 4/7 [huggingface-hub]
#    ---------------------- ----------------- 4/7 [huggingface-hub]
#    ---------------------------- ----------- 5/7 [tokenizers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------- ----- 6/7 [transformers]
#    ---------------------------------------- 7/7 [transformers]
#
# Successfully installed filelock-3.18.0 fsspec-2025.5.1 huggingface-hub-0.32.3 numpy-2.2.6 safetensors-0.5.3 tokenizers-0.21.1 transformers-4.52.4

# %%
from transformers import AutoTokenizer

# Load a pre-trained tokenizer
model_name = "meta-llama/Meta-Llama-3-8B"  # deepseek-ai/DeepSeek-V2"
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize a text
text = "The quick brown fox jumps over the lazy dog!"

encoded_text = tokenizer(text)

# Access the tokenized IDs
print(tokenizer.decode(encoded_text["input_ids"]))

print(encoded_text["input_ids"])
print(", ".join([tokenizer.decode(t) for t in encoded_text["input_ids"]]))
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# [CLS] the quick brown fox jumps over the lazy dog! [SEP]
# [101, 1996, 4248, 2829, 4419, 14523, 2058, 1996, 13971, 3899, 999, 102]
# [CLS], the, quick, brown, fox, jumps, over, the, lazy, dog, !, [SEP]
